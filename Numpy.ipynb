# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = np.linspace(0,10,10)  # X değeri 10 iken y değeri x'in küpü olduğundan 1000 olmuştur.
y = x**3

# %%
plt.plot(x,y) #Grafik çizimi
